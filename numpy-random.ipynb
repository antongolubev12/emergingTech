# %% [markdown]
# # The Numpy Random Package
# ***

# %%
#numpy is for efficient numerical arrays
import numpy as np

#Plotting.
import matplotlib.pyplot as plt

# %%
#configurations
# change the default figure size
plt.style.use('seaborn-dark-palette')

#Change graph size
plt.rcParams['figure.figsize'] = [14, 9]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
#look at the first 10 items
s[:10]
# Out:
# array([-0.02824647,  0.13812859,  0.04256656,  0.12291529,  0.13376721,
#         0.12140611, -0.01353575,  0.0752297 , -0.08870753,  0.00259008])

# %%
abs(mu - np.mean(s))
# Out:
# 0.007701282679639112

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0006762873084428939

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f=1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2
                                         /(2*sigma**2))
plt.plot(bins, f,linewidth=2, color='r')
plt.show()

# %% [markdown]
# ***
# ## References
# [1]
